# %%
pip install mysql-connector-python pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Install the MySQL Connector/Python package using pip

pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector
import pandas as pd            #import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Replace 'your_username', 'your_password', 'your_host', and 'your_database' with

connection = mysql.connector.connect(
user='root',
password='admin',
host='localhost',
database='Network_users' # write here database name 
)

# %%
cursor=connection.cursor()    #variable to connect connection

# %%
cursor.execute('SELECT * FROM MobileUsers')

# %%
df= pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in
cursor.description])

# %%
cursor.execute("select * from UserConnections")    #retrive data

# %%
userconnections=pd.DataFrame(cursor.fetchall(),columns=[desc[0] for desc in cursor.description])   #create a dataframe of a table

# %%
df.head()
# Out:
#    UserID UserName   PhoneNumber  DeviceType       OS SubscriptionType
# 0       1     John  123-456-7890  Smartphone      iOS          Premium
# 1       2    Alice  987-654-3210      Tablet  Android            Basic
# 2       3      Bob  555-123-4567  Smartphone      iOS          Premium
# 3       4    Emily  555-987-6543  Smartphone  Android            Basic
# 4       5  Charlie  555-111-2222      Tablet      iOS          Premium

# %%
userconnections.head(20)
# Out:
#     UserID      IPAddress ConnectionType
# 0        1  192.168.1.100       Ethernet
# 1        2       10.0.0.1          Wi-Fi
# 2        3     172.16.0.1       Cellular
# 3        4   192.168.2.50          Wi-Fi
# 4        5   192.168.3.75       Ethernet
# 5        6      10.10.1.1       Ethernet
# 6        7   192.168.5.20          Wi-Fi
# 7        8     172.20.0.1       Cellular
# 8        9   192.168.4.30       Ethernet
# 9       10    10.20.30.40          Wi-Fi
# 10      11    172.16.10.1       Cellular
# 11      12   192.168.6.40       Ethernet
# 12      13       10.5.6.7       Ethernet
# 13      14   192.168.7.90          Wi-Fi
# 14      15     172.30.0.1       Cellular
# 15      16   192.168.8.60       Ethernet
# 16      17    10.15.25.35          Wi-Fi
# 17      18    172.16.20.1       Cellular
# 18      19   192.168.9.70       Ethernet
# 19      20    10.50.60.70          Wi-Fi

# %%
# Handle missing values
df.dropna(inplace=True)  # Drop rows with any missing values

# %%
df.drop_duplicates(inplace=True)

# %%
df.columns
# Out:
# Index(['UserID', 'UserName', 'PhoneNumber', 'DeviceType', 'OS',
#        'SubscriptionType'],
#       dtype='object')

# %%
df
# Out:
#     UserID UserName   PhoneNumber  DeviceType       OS SubscriptionType
# 0        1     John  123-456-7890  Smartphone      iOS          Premium
# 1        2    Alice  987-654-3210      Tablet  Android            Basic
# 2        3      Bob  555-123-4567  Smartphone      iOS          Premium
# 3        4    Emily  555-987-6543  Smartphone  Android            Basic
# 4        5  Charlie  555-111-2222      Tablet      iOS          Premium
# ..     ...      ...           ...         ...      ...              ...
# 95      96   Autumn  555-454-5454  Smartphone  Android            Basic
# 96      97    Jaxon  555-676-7676  Smartphone      iOS          Premium
# 97      98  Adeline  555-898-9898      Tablet  Android            Basic
# 98      99  Grayson  555-010-1010  Smartphone      iOS          Premium
# 99     100  Lillian  555-232-3232      Tablet  Android            Basic
#
# [100 rows x 6 columns]

# %%
userconnections.describe()      #gives the complete statestical information
# Out:
#            UserID
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
df.info()      #information of table like columns,datatype,null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   UserID            100 non-null    int64
#  1   UserName          100 non-null    object
#  2   PhoneNumber       100 non-null    object
#  3   DeviceType        100 non-null    object
#  4   OS                100 non-null    object
#  5   SubscriptionType  100 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 4.8+ KB

# %%
df.isnull()         #checks if there are any null values
# Out:
#     UserID  UserName  PhoneNumber  DeviceType     OS  SubscriptionType
# 0    False     False        False       False  False             False
# 1    False     False        False       False  False             False
# 2    False     False        False       False  False             False
# 3    False     False        False       False  False             False
# 4    False     False        False       False  False             False
# ..     ...       ...          ...         ...    ...               ...
# 95   False     False        False       False  False             False
# 96   False     False        False       False  False             False
# 97   False     False        False       False  False             False
# 98   False     False        False       False  False             False
# 99   False     False        False       False  False             False
#
# [100 rows x 6 columns]

# %%
userconnections.isnull()         #checks if there are any null values
# Out:
#     UserID  IPAddress  ConnectionType
# 0    False      False           False
# 1    False      False           False
# 2    False      False           False
# 3    False      False           False
# 4    False      False           False
# ..     ...        ...             ...
# 95   False      False           False
# 96   False      False           False
# 97   False      False           False
# 98   False      False           False
# 99   False      False           False
#
# [100 rows x 3 columns]

# %%
# Save the cleaned data to a new file
df.to_csv('cleaned_data.csv', index=False)

# %%
df
# Out:
#     UserID UserName   PhoneNumber  DeviceType       OS SubscriptionType
# 0        1     John  123-456-7890  Smartphone      iOS          Premium
# 1        2    Alice  987-654-3210      Tablet  Android            Basic
# 2        3      Bob  555-123-4567  Smartphone      iOS          Premium
# 3        4    Emily  555-987-6543  Smartphone  Android            Basic
# 4        5  Charlie  555-111-2222      Tablet      iOS          Premium
# ..     ...      ...           ...         ...      ...              ...
# 95      96   Autumn  555-454-5454  Smartphone  Android            Basic
# 96      97    Jaxon  555-676-7676  Smartphone      iOS          Premium
# 97      98  Adeline  555-898-9898      Tablet  Android            Basic
# 98      99  Grayson  555-010-1010  Smartphone      iOS          Premium
# 99     100  Lillian  555-232-3232      Tablet  Android            Basic
#
# [100 rows x 6 columns]

# %%
df.shape
# Out:
# (100, 6)

# %%
userconnections.shape
# Out:
# (100, 3)

# %%
df.groupby('UserName')['DeviceType'].sum()
# Out:
# UserName
# Aaliyah        Smartphone
# Aaron              Tablet
# Addison        Smartphone
# Adeline            Tablet
# Alexander    TabletTablet
#                  ...
# Violet             Tablet
# William            Tablet
# Wyatt          Smartphone
# Zoe            Smartphone
# Zoey               Tablet
# Name: DeviceType, Length: 97, dtype: object

# %%
merge=pd.merge(df,userconnections,on='UserID',how='inner')          #joins two tables

# %%
merge                                                                 #prints merged tables
# Out:
#     UserID UserName   PhoneNumber  DeviceType       OS SubscriptionType  \
# 0        1     John  123-456-7890  Smartphone      iOS          Premium
# 1        2    Alice  987-654-3210      Tablet  Android            Basic
# 2        3      Bob  555-123-4567  Smartphone      iOS          Premium
# 3        4    Emily  555-987-6543  Smartphone  Android            Basic
# 4        5  Charlie  555-111-2222      Tablet      iOS          Premium
# ..     ...      ...           ...         ...      ...              ...
# 95      96   Autumn  555-454-5454  Smartphone  Android            Basic
# 96      97    Jaxon  555-676-7676  Smartphone      iOS          Premium
# 97      98  Adeline  555-898-9898      Tablet  Android            Basic
# 98      99  Grayson  555-010-1010  Smartphone      iOS          Premium
# 99     100  Lillian  555-232-3232      Tablet  Android            Basic
#
#          IPAddress ConnectionType
# 0    192.168.1.100       Ethernet
# ...

# %%
df = pd.DataFrame(df)

# Count the number of users for each OS
os_counts = df['OS'].value_counts()

# Plotting the graph
os_counts.plot(kind='bar')
plt.xlabel('Operating System')
plt.ylabel('Number of Users')
plt.title('Number of Users by Operating System')
plt.show()

# %%
df = pd.DataFrame(df)
# Plotting pie chart
plt.figure(figsize=(20, 5))
plt.subplot(1, 3, 2)
device_counts.plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribution of Users by Device Type')
# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()

# %%
# Plotting line chart
df = pd.DataFrame(df)

# Grouping data by DeviceType and counting unique users
device_users = df.groupby('DeviceType')['UserID'].nunique()
plt.figure(figsize=(20, 5))

plt.subplot(1, 3, 3)
device_users.plot(kind='line', marker='o')
plt.xlabel('Device Type')
plt.ylabel('Number of Unique Users')
plt.title('Unique Users by Device Type')

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()

# %%
df = pd.DataFrame(df)

# Scatter plot
plt.scatter(df['UserID'], df['PhoneNumber'])
plt.xlabel('User ID')
plt.ylabel('Phone Number')
plt.title('Scatter Plot of User ID vs Phone Number')
plt.grid(True)
plt.show()

# %%
df = pd.DataFrame(df.head(20))

# Extracting data for the bar chart
user_phone_counts = df.groupby('UserName')['PhoneNumber'].count()

# Plotting the bar chart

user_phone_counts.plot(kind='bar')
plt.xlabel('User Name')
plt.ylabel('Number of Phone Numbers')
plt.title('Number of Phone Numbers per User')
plt.xticks(rotation=45, ha='right')  # Rotating x-axis labels for better readability
plt.tight_layout()
plt.show()
